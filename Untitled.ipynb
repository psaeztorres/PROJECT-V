# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns',None)

# %%
taxi = pd.read_csv("data/taxi.csv")

# %%
# Replace 'path/to/new-york-city-boroughs.geojson' with the actual path to your GeoJSON file
gdf = gpd.read_file("C:/Users/psaez/Downloads/new-york-city-boroughs.geojson")

# %%
gdf.head()
# Out:
#             name  cartodb_id                       created_at  \
# 0  Staten Island           1 2013-03-09 02:42:03.692000+00:00
# 1         Queens           2 2013-03-09 02:42:03.692000+00:00
# 2       Brooklyn           3 2013-03-09 02:42:03.692000+00:00
# 3      Manhattan           4 2013-03-09 02:42:03.692000+00:00
# 4          Bronx           5 2013-03-09 02:42:03.692000+00:00
#
#                         updated_at  \
# 0 2013-03-09 02:42:03.989000+00:00
# 1 2013-03-09 02:42:03.989000+00:00
# 2 2013-03-09 02:42:03.989000+00:00
# 3 2013-03-09 02:42:03.989000+00:00
# 4 2013-03-09 02:42:03.989000+00:00
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 1  MULTIPOLYGON (((-73.83668 40.59495, -73.83678 ...
# 2  MULTIPOLYGON (((-73.86706 40.58209, -73.86769 ...
# 3  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 4  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...

# %%
gdf.columns
# Out:
# Index(['name', 'cartodb_id', 'created_at', 'updated_at', 'geometry'], dtype='object')

# %%
gdf['name']
# Out:
# 0    Staten Island
# 1           Queens
# 2         Brooklyn
# 3        Manhattan
# 4            Bronx
# Name: name, dtype: object

# %%
taxi['date'].max()
# Out:
# '2019-03-31'

# %%
taxi['date'].min()
# Out:
# '2019-02-28'

# %%
taxi.sample(20)
# Out:
#       Unnamed: 0.1  Unnamed: 0               pickup              dropoff  \
# 2597          2609        2609  2019-03-28 16:03:46  2019-03-28 16:05:44
# 5353          5380        5380  2019-03-15 18:18:23  2019-03-15 18:28:45
# 3811          3830        3830  2019-03-17 16:54:01  2019-03-17 16:59:39
# 3704          3723        3723  2019-03-13 22:05:44  2019-03-13 22:24:36
# 780            784         784  2019-03-31 17:00:03  2019-03-31 17:14:41
# 6330          6380        6380  2019-03-22 19:14:43  2019-03-22 19:21:00
# 4738          4763        4763  2019-03-16 19:13:22  2019-03-16 19:53:19
# 4953          4980        4980  2019-03-23 07:54:29  2019-03-23 07:57:13
# 3156          3171        3171  2019-03-20 07:31:39  2019-03-20 07:44:06
# 3657          3676        3676  2019-03-10 14:02:58  2019-03-10 14:11:32
# 5696          5733        5733  2019-03-11 15:26:54  2019-03-11 15:31:16
# 2908          2921        2921  2019-03-22 08:41:28  2019-03-22 08:46:48
# ...
